# %%
'''
    20260119:
        从多个实验中抽取 open-ended ans (尤其是random  mask的话 设置3个)
        

'''
# Out:
# '\n\n'

# %%
from datetime import datetime
import os

# %%
dt = datetime.now().strftime("%Y%m%d")

# %%
'''
生成judge的prompt

'''

prompt_template = (
    "You are a neutral judge. Score the model’s answer from 1 to 10 based on correctness, completeness, clarity, and usefulness.\n"
    "Respond ONLY in this JSON format:\n"
    '{{"score": <1-10>, "reason": "<brief reason>"}}\n\n'
    "Question:\n{question}\n\n"
    "Answer:\n{answer}"
)

def get_judge_promt(x):
    return prompt_template.format(question= x[0], answer= x[1])

# %%
# add judge prompt
def save_judge_prompt(ds_final, save_dir):
    df_final = ds_final.to_pandas()
    df_final['judge_prompt'] = df_final[['text','answer']].apply(lambda x: prompt_template.format(question= x[0], answer= x[1]), axis=1)

    ds_final = datasets.Dataset.from_pandas(df_final)
    
    final_path = os.path.join(save_dir, f"{dt}_generation_all_models.json")
    ds_final.to_json(final_path, force_ascii=False)
    print(f"[Saved final merged] {final_path}")

# %% [markdown]
# ## 20260119

# %%
save_dir='/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_0_1_2_total'
os.makedirs(save_dir, exist_ok=True)

# %%
import pandas as pd
import datasets

# %%
data1 = datasets.load_dataset('json', data_files=
                              [
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_org_model_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_LAPE_en_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_LAPE_vi_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_LAPE_zh_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_th_1_selected_LRP_kur_res_en_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_th_1_selected_LRP_kur_res_vi_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260115_newrandom5000samples_cal_llama2_7b_base/20260119_LRP_generation_th_1_selected_LRP_kur_res_zh_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_en_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_vi_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_zh_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_1/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_en_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_1/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_vi_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_1/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_zh_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_2/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_en_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_2/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_vi_zscore_open_ended.json',
                                  '/root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_2/20260119_LRP_generation_th_1_selected_LRP_kur_res_random_zh_zscore_open_ended.json',


                                 
                              ]
                             
                             
                             )

# %%
len(data1['train'])
# Out:
# 3360

# %%
df_data1 = data1['train'].to_pandas()

# %%
df_data1.head(2)
# Out:
#                                                 text lang  __index_level_0__  \
# 0       How can I improve my time management skills?   en                  0
# 1  What are the most effective ways to deal with ...   en                  1
#
#                                               answer            model_type
# 0  How do you manage your time effectively?\nWhat...  org_model|open_ended
# 1  What is the best way to manage stress?\nHow ca...  org_model|open_ended

# %%
df_data1['model_type'].value_counts()
# Out:
# model_type
# th_1_selected_LRP_kur_res_random_zh_zscore|open_ended    630
# th_1_selected_LRP_kur_res_random_vi_zscore|open_ended    630
# th_1_selected_LRP_kur_res_random_en_zscore|open_ended    630
# org_model|open_ended                                     210
# LAPE_en|open_ended                                       210
# LAPE_vi|open_ended                                       210
# th_1_selected_LRP_kur_res_vi_zscore|open_ended           210
# th_1_selected_LRP_kur_res_en_zscore|open_ended           210
# LAPE_zh|open_ended                                       210
# th_1_selected_LRP_kur_res_zh_zscore|open_ended           210
# Name: count, dtype: int64

# %%
save_judge_prompt(data1['train'], save_dir)
# Out:
# /tmp/ipykernel_5945/2626489279.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_final['judge_prompt'] = df_final[['text','answer']].apply(lambda x: prompt_template.format(question= x[0], answer= x[1]), axis=1)
# Creating json from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# [Saved final merged] /root/autodl-fs/LRP/open_ended_data_generation/20260119_newrandom5000samples_cal_llama2_7b_base_random_mask_0_1_2_total/20260119_generation_all_models.json
